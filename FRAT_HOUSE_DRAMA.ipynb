# %% [markdown]
# <a href="https://colab.research.google.com/github/austinm21/Finalproject0.1/blob/master/FRAT_HOUSE_DRAMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time #This slows the text down at some points

#WILL ACCEPT UPPERCASE OR LOWERCASE
answer_A = ["A", "a"]
answer_B = ["B", "b"]
answer_C = ["C", "c"]
yes = ["Y", "y", "yes"]
no = ["N", "n", "no"]

#THINGS YOU EARN
respect = 0
beer = 0

needed = ("\nUse only A, B, or C\n") #Prevents too much repeitition 

#The story has multiple sections

''' This function starts out the whole story. It gives you the opening scenario
and then asks which house you want to go to. Then, depending on what choice you 
go with, it will take you to another section. '''

def start():
  print("WHAT UP BRO? WHAT'S YOUR NAME?")
  input()
  print ("It's your first weekend in college and you have no friends. You think that it is best to go to a party so you can meet some new people. But you have one huge problem. There are three fraternities that you can pick from. Which one do you want to go to?:")
  time.sleep(1)
  print ("""  A. Sigma Apple Pie
  B. Kappa Kappa Popcorn
  C. Theta Mashed Potatoes""")
  choice = input(">>> ") #This is your first option
  if choice in answer_A:
    option_sigapplepie()
  elif choice in answer_B:
    print ("\nWell, they didn't Let you in because you have no females with you. Better luck next weekend ya square!"
    "\n\nMAYBE PICK A DIFFRENT HOUSE NEXT TIME!")
  elif choice in answer_C:
    option_tater()
  else:
    print (needed)
    intro()

'''This function takes you to the set of options that will appear if you choose
Sigma Apple Pie in the first question. It then asks 3 more questions and has
multiple choice again '''

def option_sigapplepie(): 
  print ("\nYou meet your first Frat Bro, His Name is Chad. He starts a conversation with you. What do you think you should do?:")
  time.sleep(1)
  print ("""  A. Get to know him and the rest of the bros 
  B. Ignore Him
  C. Tell him a silly joke""")
  choice = input(">>> ")
  if choice in answer_A:
    option_tater()
  elif choice in answer_B:
    print ("\nWell that is probably the worst way to make friends. " 
    "You will probably be lonley forever if you keep acting this way. "
    "How will a frat ever want you? \n\nSTOP BEING SOFT AND TRY AGAIN NEXT WEEKEND")
  elif choice in answer_C:
    option_kkp()
  else:
    print (needed)
    option_sigapplepie()


'''This function is what appears if you choose to tell him a silly joke 
you can then pick what to do from there. If you choose to keep talking to him 
it will give you a respect point, but if you choose no, it will not let you 
join the fraternity if you ask about it opposed if you do keep talking'''

def option_kkp():
  print ("\nHe doesn't think that you are funny at all. Should you keep talking to him? Y/N?")
  choice = input(">>> ")
  if choice in yes:
    respect = 1 #allows you you to have "respect points"
  else:
    respect = 0
  print ("\nHe is starting to look at you like the loser that you really are. You should probably talk about something else. What will you talk about?")
  time.sleep(1)
  print ("""  A. Ask him about school
  B. Ask about the fraternity
  C. Ask for some Alcohol""")
  choice = input(">>> ")
  if choice in answer_A:
    print ("\nReally? It's the weekend. Nobody wants to talk about that "
    "\n\nSTOP BEING SO DAMN SOFT")
  elif choice in answer_B:
   if respect > 0:
    print ("\nYou just got major respect! "
    "He gets so excited that you asked he forgot about your ridiculous joke. "
    "He even asks if you are thinking about becoming a brother some day. "
    "You now have major clout!"
    "\n\nYou're going to get all the girls now!!!!!")
   else: 
     print ("\nHE THINKS THAT YOU'RE A HEADASS AND TELLS YOU TO GTFO! \n\nTHE SIGMA APPLE PIE FRATERNITY HATES YOUR GUTS!")
  elif choice in answer_C:
    print ("He says that it's BYOB and you're out of luck. BUT..... ")
    option_tater()
  else:
    print (needed)
    option_kkp()

'''This function will pop up if you go through the correct route by answering C 
in the kkp function or if you pick C in the very first question'''    

def option_tater():
  print ("\nThese guys seem really cool, but they don't have any alcohol. What will you do?:")
  time.sleep(1)
  print ("""  A. Ask them for some
  B. Leave and never come back
  C. Go to the kitchen and try and steal some""")
  choice = input(">>> ")
  if choice in answer_A:
    print ("They tell you to bring your own and stop being a mooch. "
    "\n\nYOU ARE NOW BLACKLISTED FROM THE FRATERNITY!")
  elif choice in answer_B:
    print ("\nWell that's one way to never make friends "
    "\nMaybe bring some of your own next time")
  elif choice in answer_C:
    option_town()
  else:
    print (needed)
    option_steal()
    
    ''' This funciton will always come up if you pick C in the tater option, 
    within this function you can also either choose to grab a beer or not and that
    will determine if you get beer points that will determine your final outcome'''

def option_steal():
  print ("\nYou get past all of the people and there is a full case of Busch Light. Do you take one? Y/N")
  choice = input(">>> ")
  if choice in yes:
    beer = 1 #adds a beer point
  else:
    beer = 0
  print ("OHHHHHH WOW!!!")
  time.sleep(1)
  if beer > 0:
    print ("\nYou end up grabbing two! This could have been a giant mistake! "
    "You then see a brother of the Frat walk into the Kitchen! "
    "He asks you what you were doing. You tell him that you were grabbing one for Brad. He then asks you if you're a future recruit."
    "\n\nYour poor decision has lead you to a very fortunate outcome. You are given a bid to the fraternity and hope to become president senior year. YOU NOW HAVE FRIENDS. THE END")
  else: #What occurs if beer isn't added 
     print ("\nLooks like tonight you're going to be biiiiiiig sober!"
     "\n\nYou really need to stop being lame!!!!")

start()
# Out:
# WHAT UP BRO? WHAT'S YOUR NAME?
# Luke
# It's your first weekend in college and you have no friends. You think that it is best to go to a party so you can meet some new people. But you have one huge problem. There are three fraternities that you can pick from. Which one do you want to go to?:
#   A. Sigma Apple Pie
#   B. Kappa Kappa Popcorn
#   C. Theta Mashed Potatoes
# >>> C
#
# These guys seem really cool, but they don't have any alcohol. What will you do?:
#   A. Ask them for some
#   B. Leave and never come back
#   C. Go to the kitchen and try and steal some
# >>> A
# They tell you to bring your own and stop being a mooch.
#
# YOU ARE NOW BLACKLISTED FROM THE FRATERNITY!
